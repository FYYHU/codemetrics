# %%
import pandas as pd

# %%
code_metric_df = pd.read_csv("codemetrics.csv", sep=";")
simian_dupe_df = pd.read_csv("simian_duplicates.csv")

# %%
simian_dupe_df
# Out:
#                            fingerprint  duplicate_lines  \
# 0     f6de6100b7f64f3daaf981fff928ca78                6
# 1     f6de6100b7f64f3daaf981fff928ca78                6
# 2     c8b165a9b79d37bbf819917f1bc9aa44                6
# 3     c8b165a9b79d37bbf819917f1bc9aa44                6
# 4     348ba8a4deab41470301b3159dbd8ad0                6
# ...                                ...              ...
# 8465  b8487164706788218a8e2471a9a7b0bc              183
# 8466  749b38b529a475a032d689f8eb9e3bc5              187
# 8467  749b38b529a475a032d689f8eb9e3bc5              187
# 8468  6762c3b077114eb2401a2a38521c94f4              377
# 8469  6762c3b077114eb2401a2a38521c94f4              377
#
#                                               file_path  start_line  end_line
# 0     Rubberduck/Rubberduck.Parsing/Symbols/Property...          36        41
# 1     Rubberduck/Rubberduck.Parsing/Symbols/ModuleBo...          37        42
# 2     Rubberduck/Rubberduck.CodeAnalysis/QuickFixes/...          74        80
# 3     Rubberduck/Rubberduck.CodeAnalysis/QuickFixes/...          13        19
# 4     Rubberduck/RubberduckTests/Inspections/Integer...         109       117
# ...                                                 ...         ...       ...
# 8465  Rubberduck/RubberduckTests/Grammar/ResolverTes...        5854      6049
# 8466  Rubberduck/RubberduckTests/VBEditor/Variants/V...           9       222
# 8467  Rubberduck/RubberduckTests/ComMock/VariantConv...           9       218
# 8468  Rubberduck/Rubberduck.Resources/Inspections/In...          43      1166
# 8469  Rubberduck/Rubberduck.Resources/Inspections/In...          43      1167
#
# [8470 rows x 5 columns]

# %%
# Extract second part of the directory
simian_dupe_df['name_space'] =simian_dupe_df['file_path'].apply(lambda x: x.split('/')[1] if len(x.split('/')) > 1 else None)

# %%
simian_dupe_df
# Out:
#                            fingerprint  duplicate_lines  \
# 0     f6de6100b7f64f3daaf981fff928ca78                6
# 1     f6de6100b7f64f3daaf981fff928ca78                6
# 2     c8b165a9b79d37bbf819917f1bc9aa44                6
# 3     c8b165a9b79d37bbf819917f1bc9aa44                6
# 4     348ba8a4deab41470301b3159dbd8ad0                6
# ...                                ...              ...
# 8465  b8487164706788218a8e2471a9a7b0bc              183
# 8466  749b38b529a475a032d689f8eb9e3bc5              187
# 8467  749b38b529a475a032d689f8eb9e3bc5              187
# 8468  6762c3b077114eb2401a2a38521c94f4              377
# 8469  6762c3b077114eb2401a2a38521c94f4              377
#
#                                               file_path  start_line  end_line  \
# 0     Rubberduck/Rubberduck.Parsing/Symbols/Property...          36        41
# 1     Rubberduck/Rubberduck.Parsing/Symbols/ModuleBo...          37        42
# 2     Rubberduck/Rubberduck.CodeAnalysis/QuickFixes/...          74        80
# 3     Rubberduck/Rubberduck.CodeAnalysis/QuickFixes/...          13        19
# 4     Rubberduck/RubberduckTests/Inspections/Integer...         109       117
# ...                                                 ...         ...       ...
# 8465  Rubberduck/RubberduckTests/Grammar/ResolverTes...        5854      6049
# 8466  Rubberduck/RubberduckTests/VBEditor/Variants/V...           9       222
# 8467  Rubberduck/RubberduckTests/ComMock/VariantConv...           9       218
# 8468  Rubberduck/Rubberduck.Resources/Inspections/In...          43      1166
# 8469  Rubberduck/Rubberduck.Resources/Inspections/In...          43      1167
#
#                    name_space
# 0          Rubberduck.Parsing
# 1          Rubberduck.Parsing
# 2     Rubberduck.CodeAnalysis
# 3     Rubberduck.CodeAnalysis
# 4             RubberduckTests
# ...                       ...
# 8465          RubberduckTests
# 8466          RubberduckTests
# 8467          RubberduckTests
# 8468     Rubberduck.Resources
# 8469     Rubberduck.Resources
#
# [8470 rows x 6 columns]

# %%
name_space_group_df = simian_dupe_df.groupby('name_space').sum(numeric_only=True)

# %%
code_metric_df[(code_metric_df["Namespace"]=="Rubberduck.CodeAnalysis") & (code_metric_df["Scope"]=="Namespace")]
# Out:
#            Scope                          Project                Namespace  \
# 29838  Namespace  Rubberduck.CodeAnalysis (Debug)  Rubberduck.CodeAnalysis
#
#       Type Member  Maintainability Index  Cyclomatic Complexity  \
# 29838                                 88                     55
#
#        Depth of Inheritance  Class Coupling  Lines of Source code  \
# 29838                   1.0              10                   515
#
#        Lines of Executable code
# 29838                        56

# %%
name_space_group_df.reset_index()
# Out:
#                      name_space  duplicate_lines  start_line  end_line
# 0       Rubberduck.CodeAnalysis              751       10450     11509
# 1               Rubberduck.Core             1858       16702     19520
# 2               Rubberduck.Main              321        8879      9264
# 3            Rubberduck.Parsing             4226      112389    117029
# 4       Rubberduck.Refactorings              538        4976      5731
# 5     Rubberduck.RegexAssistant              150         151       560
# 6          Rubberduck.Resources             2156       27907     33790
# 7        Rubberduck.UnitTesting               19         175       191
# 8          Rubberduck.VBEEditor              320        2368      2769
# 9       Rubberduck.VBEditor.VB6             1051        4317      6597
# 10      Rubberduck.VBEditor.VBA             1062        5603      7880
# 11       RubberduckCodeAnalysis               20          65       100
# 12              RubberduckTests            76007     6730140   6821416
# 13  RubberduckTestsCodeAnalysis              378       15388     16202

# %%
temp = name_space_group_df.reset_index().merge(code_metric_df, left_on="name_space", right_on="Namespace")
cleanup = temp[temp["Scope"] == "Namespace"].drop(columns=["Type", "Member", "Namespace"])

# %%
cleanup
# Out:
#                      name_space  duplicate_lines  start_line  end_line  \
# 0       Rubberduck.CodeAnalysis              751       10450     11509
# 110          Rubberduck.Parsing             4226      112389    117029
# 222     Rubberduck.Refactorings              538        4976      5731
# 918   Rubberduck.RegexAssistant              150         151       560
# 1025       Rubberduck.Resources             2156       27907     33790
# 1808     Rubberduck.UnitTesting               19         175       191
# 2473     Rubberduck.UnitTesting               19         175       191
# 2637    Rubberduck.VBEditor.VB6             1051        4317      6597
# 2644    Rubberduck.VBEditor.VBA             1062        5603      7880
# 2650            RubberduckTests            76007     6730140   6821416
#
#           Scope                            Project  Maintainability Index  \
# 0     Namespace    Rubberduck.CodeAnalysis (Debug)                     88
# 110   Namespace         Rubberduck.Parsing (Debug)                     82
# 222   Namespace    Rubberduck.Refactorings (Debug)                     92
# 918   Namespace  Rubberduck.RegexAssistant (Debug)                     82
# 1025  Namespace       Rubberduck.Resources (Debug)                     84
# 1808  Namespace            Rubberduck.Main (Debug)                     88
# 2473  Namespace     Rubberduck.UnitTesting (Debug)                     90
# 2637  Namespace    Rubberduck.VBEditor.VB6 (Debug)                     82
# 2644  Namespace    Rubberduck.VBEditor.VBA (Debug)                     69
# 2650  Namespace            RubberduckTests (Debug)                     71
#
#       Cyclomatic Complexity  Depth of Inheritance  Class Coupling  \
# 0                        55                   1.0              10
# 110                     215                   2.0              80
# 222                     527                   2.0             155
# 918                     116                   1.0              36
# 1025                    278                   2.0              28
# 1808                    562                   2.0             148
# 2473                    164                   2.0              80
# 2637                      7                   1.0               6
# 2644                      9                   1.0              10
# 2650                    103                   1.0              84
#
#       Lines of Source code  Lines of Executable code
# 0                      515                        56
# 110                   1136                       245
# 222                   3357                       616
# 918                    623                       168
# 1025                  2999                       358
# 1808                     0                       635
# 2473                   847                       280
# 2637                    30                         8
# 2644                    68                        21
# 2650                  1465                       403
