# %%
import pandas as pd

# %%
code_metric_df = pd.read_csv("codemetrics.csv", sep=";")
simian_dupe_df = pd.read_csv("simian_duplicates.csv")

# %%
simian_dupe_df
# Out:
#                            fingerprint  duplicate_lines  \
# 0     f6de6100b7f64f3daaf981fff928ca78                6
# 1     f6de6100b7f64f3daaf981fff928ca78                6
# 2     c8b165a9b79d37bbf819917f1bc9aa44                6
# 3     c8b165a9b79d37bbf819917f1bc9aa44                6
# 4     348ba8a4deab41470301b3159dbd8ad0                6
# ...                                ...              ...
# 8465  b8487164706788218a8e2471a9a7b0bc              183
# 8466  749b38b529a475a032d689f8eb9e3bc5              187
# 8467  749b38b529a475a032d689f8eb9e3bc5              187
# 8468  6762c3b077114eb2401a2a38521c94f4              377
# 8469  6762c3b077114eb2401a2a38521c94f4              377
#
#                                               file_path  start_line  end_line
# 0     Rubberduck/Rubberduck.Parsing/Symbols/Property...          36        41
# 1     Rubberduck/Rubberduck.Parsing/Symbols/ModuleBo...          37        42
# ...

# %%
# Extract second part of the directory
simian_dupe_df['file_space'] =simian_dupe_df['file_path'].apply(lambda x: x.split('/')[1] if len(x.split('/')) > 1 else None)

# %%
simian_dupe_df
# Out:
#                            fingerprint  duplicate_lines  \
# 0     f6de6100b7f64f3daaf981fff928ca78                6
# 1     f6de6100b7f64f3daaf981fff928ca78                6
# 2     c8b165a9b79d37bbf819917f1bc9aa44                6
# 3     c8b165a9b79d37bbf819917f1bc9aa44                6
# 4     348ba8a4deab41470301b3159dbd8ad0                6
# ...                                ...              ...
# 8465  b8487164706788218a8e2471a9a7b0bc              183
# 8466  749b38b529a475a032d689f8eb9e3bc5              187
# 8467  749b38b529a475a032d689f8eb9e3bc5              187
# 8468  6762c3b077114eb2401a2a38521c94f4              377
# 8469  6762c3b077114eb2401a2a38521c94f4              377
#
#                                               file_path  start_line  end_line  \
# 0     Rubberduck/Rubberduck.Parsing/Symbols/Property...          36        41
# 1     Rubberduck/Rubberduck.Parsing/Symbols/ModuleBo...          37        42
# ...

# %%
file_space_group_df = simian_dupe_df.groupby('file_space').sum(numeric_only=True)

# %%
file_space_group_df
# Out:
#                              duplicate_lines  start_line  end_line
# file_space
# Rubberduck.CodeAnalysis                  751       10450     11509
# Rubberduck.Core                         1858       16702     19520
# Rubberduck.Main                          321        8879      9264
# Rubberduck.Parsing                      4226      112389    117029
# Rubberduck.Refactorings                  538        4976      5731
# Rubberduck.RegexAssistant                150         151       560
# Rubberduck.Resources                    2156       27907     33790
# Rubberduck.UnitTesting                    19         175       191
# Rubberduck.VBEEditor                     320        2368      2769
# Rubberduck.VBEditor.VB6                 1051        4317      6597
# Rubberduck.VBEditor.VBA                 1062        5603      7880
# RubberduckCodeAnalysis                    20          65       100
# RubberduckTests                        76007     6730140   6821416
# ...

# %%
cleaned_code_metric_df = code_metric_df[code_metric_df["Scope"]=="Assembly"]
cleaned_code_metric_df["Project"] = cleaned_code_metric_df["Project"].str.replace(r'\s*\(Debug\)', '', regex=True)
# Out:
# /tmp/ipykernel_12888/437327404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_code_metric_df["Project"] = cleaned_code_metric_df["Project"].str.replace(r'\s*\(Debug\)', '', regex=True)

# %%
cleaned_code_metric_df
# Out:
#           Scope                      Project Namespace Type Member  \
# 0      Assembly              Rubberduck.Core
# 8098   Assembly              RubberduckTests
# 15643  Assembly           Rubberduck.Parsing
# 28518  Assembly              Rubberduck.Main
# 29837  Assembly      Rubberduck.CodeAnalysis
# 33125  Assembly      Rubberduck.Refactorings
# 35937  Assembly          Rubberduck.VBEditor
# 39907  Assembly      Rubberduck.VBEditor.VBA
# 40797  Assembly      Rubberduck.VBEditor.VB6
# 41674  Assembly       Rubberduck.UnitTesting
# 42002  Assembly     Rubberduck.SmartIndenter
# 42394  Assembly  Rubberduck.SettingsProvider
# 42495  Assembly    Rubberduck.RegexAssistant
# 42769  Assembly         Rubberduck.Resources
# 45673  Assembly       Rubberduck.Interaction
# 45730  Assembly       Rubberduck.InternalApi
# 45779  Assembly        Rubberduck.Deployment
#
#        Maintainability Index  Cyclomatic Complexity  Depth of Inheritance  \
# ...

# %%
print(cleaned_code_metric_df.drop(columns=["Namespace","Type", "Member", "Scope"]).to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# Project & Maintainability Index & Cyclomatic Complexity & Depth of Inheritance & Class Coupling & Lines of Source code & Lines of Executable code \\
# \midrule
# Rubberduck.Core & 85 & 8105 & 11.000000 & 1245 & 35498 & 11130 \\
# RubberduckTests & 72 & 7961 & 4.000000 & 1239 & 142331 & 37668 \\
# Rubberduck.Parsing & 87 & 15165 & 5.000000 & 985 & 79267 & 22957 \\
# Rubberduck.Main & 87 & 1345 & 7.000000 & 523 & 3975 & 1899 \\
# Rubberduck.CodeAnalysis & 85 & 4245 & 5.000000 & 493 & 24063 & 5320 \\
# Rubberduck.Refactorings & 86 & 3241 & 4.000000 & 468 & 15559 & 4506 \\
# Rubberduck.VBEditor & 89 & 3037 & 5.000000 & 407 & 16724 & 3743 \\
# Rubberduck.VBEditor.VBA & 85 & 1391 & 3.000000 & 248 & 4057 & 1232 \\
# Rubberduck.VBEditor.VB6 & 84 & 1314 & 3.000000 & 202 & 3391 & 1034 \\
# Rubberduck.UnitTesting & 90 & 325 & 3.000000 & 124 & 1426 & 431 \\
# Rubberduck.SmartIndenter & 85 & 513 & 2.000000 & 54 & 1567 & 538 \\
# ...

# %%
temp = file_space_group_df.reset_index().merge(cleaned_code_metric_df, left_on="file_space", right_on="Project")
cleanup = temp.drop(columns=["Type", "Member", "Namespace", "start_line", "end_line"])

# %%
cleanup
# Out:
#                    file_space  duplicate_lines     Scope  \
# 0     Rubberduck.CodeAnalysis              751  Assembly
# 1             Rubberduck.Core             1858  Assembly
# 2             Rubberduck.Main              321  Assembly
# 3          Rubberduck.Parsing             4226  Assembly
# 4     Rubberduck.Refactorings              538  Assembly
# 5   Rubberduck.RegexAssistant              150  Assembly
# 6        Rubberduck.Resources             2156  Assembly
# 7      Rubberduck.UnitTesting               19  Assembly
# 8     Rubberduck.VBEditor.VB6             1051  Assembly
# 9     Rubberduck.VBEditor.VBA             1062  Assembly
# 10            RubberduckTests            76007  Assembly
#
#                       Project  Maintainability Index  Cyclomatic Complexity  \
# 0     Rubberduck.CodeAnalysis                     85                   4245
# 1             Rubberduck.Core                     85                   8105
# ...

# %%
print(cleanup.drop(columns=["Scope","Project"]).to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# file_space & duplicate_lines & Maintainability Index & Cyclomatic Complexity & Depth of Inheritance & Class Coupling & Lines of Source code & Lines of Executable code \\
# \midrule
# Rubberduck.CodeAnalysis & 751 & 85 & 4245 & 5.000000 & 493 & 24063 & 5320 \\
# Rubberduck.Core & 1858 & 85 & 8105 & 11.000000 & 1245 & 35498 & 11130 \\
# Rubberduck.Main & 321 & 87 & 1345 & 7.000000 & 523 & 3975 & 1899 \\
# Rubberduck.Parsing & 4226 & 87 & 15165 & 5.000000 & 985 & 79267 & 22957 \\
# Rubberduck.Refactorings & 538 & 86 & 3241 & 4.000000 & 468 & 15559 & 4506 \\
# Rubberduck.RegexAssistant & 150 & 83 & 255 & 1.000000 & 45 & 1334 & 314 \\
# Rubberduck.Resources & 2156 & 86 & 1273 & 2.000000 & 28 & 12571 & 1431 \\
# Rubberduck.UnitTesting & 19 & 90 & 325 & 3.000000 & 124 & 1426 & 431 \\
# Rubberduck.VBEditor.VB6 & 1051 & 84 & 1314 & 3.000000 & 202 & 3391 & 1034 \\
# Rubberduck.VBEditor.VBA & 1062 & 85 & 1391 & 3.000000 & 248 & 4057 & 1232 \\
# ...

# %%
cleanup.set_index("file_space").corr(numeric_only=True)
# Out:
#                           duplicate_lines  Maintainability Index  \
# duplicate_lines                  1.000000              -0.913030
# Maintainability Index           -0.913030               1.000000
# Cyclomatic Complexity            0.323397              -0.218196
# Depth of Inheritance            -0.032434               0.079090
# Class Coupling                   0.557129              -0.471025
# Lines of Source code             0.875554              -0.754440
# Lines of Executable code         0.849267              -0.725358
#
#                           Cyclomatic Complexity  Depth of Inheritance  \
# duplicate_lines                        0.323397             -0.032434
# Maintainability Index                 -0.218196              0.079090
# Cyclomatic Complexity                  1.000000              0.456324
# Depth of Inheritance                   0.456324              1.000000
# Class Coupling                         0.818785              0.722996
# ...

# %%
print(cleanup.set_index("file_space").corr(numeric_only=True).to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
#  & duplicate_lines & Maintainability Index & Cyclomatic Complexity & Depth of Inheritance & Class Coupling & Lines of Source code & Lines of Executable code \\
# \midrule
# duplicate_lines & 1.000000 & -0.913030 & 0.323397 & -0.032434 & 0.557129 & 0.875554 & 0.849267 \\
# Maintainability Index & -0.913030 & 1.000000 & -0.218196 & 0.079090 & -0.471025 & -0.754440 & -0.725358 \\
# Cyclomatic Complexity & 0.323397 & -0.218196 & 1.000000 & 0.456324 & 0.818785 & 0.735894 & 0.772745 \\
# Depth of Inheritance & -0.032434 & 0.079090 & 0.456324 & 1.000000 & 0.722996 & 0.173419 & 0.225306 \\
# Class Coupling & 0.557129 & -0.471025 & 0.818785 & 0.722996 & 1.000000 & 0.789199 & 0.825648 \\
# Lines of Source code & 0.875554 & -0.754440 & 0.735894 & 0.173419 & 0.789199 & 1.000000 & 0.995989 \\
# Lines of Executable code & 0.849267 & -0.725358 & 0.772745 & 0.225306 & 0.825648 & 0.995989 & 1.000000 \\
# \bottomrule
# \end{tabular}
